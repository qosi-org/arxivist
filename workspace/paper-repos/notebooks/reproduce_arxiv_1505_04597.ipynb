# %% [markdown]
# # Reproduce U-Net (arxiv_1505_04597)
# Unpadded convs, crop-and-concat skips. 572x572 -> 388x388x2.

# %%
import torch, torch.nn as nn
import sys; sys.path.append('..')
from src.unet import UNet

# %%
model = UNet(1,2)
x = torch.randn(1,1,572,572)
print(model(x).shape)  # torch.Size([1, 2, 388, 388])
